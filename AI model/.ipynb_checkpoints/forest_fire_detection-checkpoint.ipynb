# %%
import tensorflow as tf
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

# %%
training_data_genetation=ImageDataGenerator(
    rescale=1./255,
    vertical_flip=True,
    horizontal_flip=True,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
)

testing_data_generation=ImageDataGenerator(
    rescale=1./255,
    vertical_flip=True,
)

# %%
training_set=training_data_genetation.flow_from_directory(
    r'C:\Users\sk620\Desktop\Major1\dataset\training',
    target_size=(64,64),
    color_mode='rgb',
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 9435 images belonging to 2 classes.

# %%
testing_set=training_data_genetation.flow_from_directory(
    r'C:\Users\sk620\Desktop\Major1\dataset\testing',
    target_size=(64,64),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 3706 images belonging to 1 classes.

# %%
cnn=tf.keras.Sequential()

cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,padding='same',activation=tf.keras.layers.LeakyReLU(alpha=0.01),input_shape=[64,64,3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2))

cnn.add(tf.keras.layers.Conv2D(filters=128,kernel_size=3,padding='same',activation=tf.keras.layers.LeakyReLU(alpha=0.01)))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2))

cnn.add(tf.keras.layers.Conv2D(filters=256,kernel_size=3,padding='same',activation=tf.keras.layers.LeakyReLU(alpha=0.01)))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2))

cnn.add(tf.keras.layers.Conv2D(filters=256,kernel_size=3,padding='same',activation=tf.keras.layers.LeakyReLU(alpha=0.01)))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2))

cnn.add(tf.keras.layers.Conv2D(filters=1024,kernel_size=3,padding='same',activation=tf.keras.layers.LeakyReLU(alpha=0.01)))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2))

cnn.add(tf.keras.layers.Flatten())

cnn.add(tf.keras.layers.Dense(units=256,activation=tf.keras.layers.LeakyReLU(alpha=0.01)))

cnn.add(tf.keras.layers.Dense(units=128,activation=tf.keras.layers.LeakyReLU(alpha=0.01)))

cnn.add(tf.keras.layers.Dense(units=1,activation="sigmoid"))

# %%
checkpoint=tf.keras.callbacks.ModelCheckpoint(r'C:\Users\sk620\Desktop\Major1\archive\fire_and_smoke',
                                            monitor='val_loss',mode="min",
                                            save_best_only=True)

callbacks=checkpoint

# %%
cnn.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
cnn.fit(
    x=training_set,
    validation_data=testing_set,
    epochs=30,callbacks=callbacks
)
# Out:
# Epoch 1/30
# 295/295 [==============================] - ETA: 0s - loss: 0.1903 - accuracy: 0.9324INFO:tensorflow:Assets written to: C:\Users\sk620\Desktop\Major1\archive\fire_and_smoke\assets
# INFO:tensorflow:Assets written to: C:\Users\sk620\Desktop\Major1\archive\fire_and_smoke\assets
# 295/295 [==============================] - 438s 1s/step - loss: 0.1903 - accuracy: 0.9324 - val_loss: 2.1769 - val_accuracy: 0.4746
# Epoch 2/30
# 295/295 [==============================] - ETA: 0s - loss: 0.1120 - accuracy: 0.9640INFO:tensorflow:Assets written to: C:\Users\sk620\Desktop\Major1\archive\fire_and_smoke\assets
# INFO:tensorflow:Assets written to: C:\Users\sk620\Desktop\Major1\archive\fire_and_smoke\assets
# 295/295 [==============================] - 353s 1s/step - loss: 0.1120 - accuracy: 0.9640 - val_loss: 1.8721 - val_accuracy: 0.4995
# Epoch 3/30
# 295/295 [==============================] - 342s 1s/step - loss: 0.1056 - accuracy: 0.9679 - val_loss: 2.7187 - val_accuracy: 0.5197
# Epoch 4/30
# 295/295 [==============================] - 338s 1s/step - loss: 0.1024 - accuracy: 0.9684 - val_loss: 2.0680 - val_accuracy: 0.5127
# Epoch 5/30
# 295/295 [==============================] - 417s 1s/step - loss: 0.0811 - accuracy: 0.9742 - val_loss: 2.6608 - val_accuracy: 0.5035
# Epoch 24/30
# 295/295 [==============================] - 563s 2s/step - loss: 0.0751 - accuracy: 0.9755 - val_loss: 2.5888 - val_accuracy: 0.5162
# Epoch 25/30
# 295/295 [==============================] - 382s 1s/step - loss: 0.0808 - accuracy: 0.9740 - val_loss: 2.2802 - val_accuracy: 0.5103
# Epoch 26/30
# 295/295 [==============================] - 339s 1s/step - loss: 0.0782 - accuracy: 0.9762 - val_loss: 3.0171 - val_accuracy: 0.5103
# Epoch 27/30
# 295/295 [==============================] - 340s 1s/step - loss: 0.0762 - accuracy: 0.9757 - val_loss: 3.1086 - val_accuracy: 0.4989
# Epoch 28/30
# 295/295 [==============================] - 343s 1s/step - loss: 0.0764 - accuracy: 0.9762 - val_loss: 2.6763 - val_accuracy: 0.4984
# Epoch 29/30
# 295/295 [==============================] - 343s 1s/step - loss: 0.0731 - accuracy: 0.9759 - val_loss: 3.1326 - val_accuracy: 0.5076
# Epoch 30/30
# 295/295 [==============================] - 340s 1s/step - loss: 0.0765 - accuracy: 0.9763 - val_loss: 3.5630 - val_accuracy: 0.4933

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data=pd.read_csv(r'C:\Users\sk620\Desktop\Major1\accuracy_value.csv',delimiter=',')
data
# Out:
#     epoch  relu (Adam)  leaky relu (Adam)  relu (RMSprop)  \
# 0       1       0.9671             0.9731          0.9664
# 1       2       0.9841             0.9750          0.9838
# 2       3       0.9873             0.9837          0.9851
# 3       4       0.9808             0.9861          0.9857
# 4       5       0.9878             0.9897          0.9818
# 5       6       0.9919             0.9905          0.9817
# 6       7       0.9910             0.9918          0.9854
# 7       8       0.9924             0.9916          0.9843
# 8       9       0.9937             0.9943          0.9872
# 9      10       0.9916             0.9926          0.9857
# 10     11       0.9931             0.9928          0.9896
# 11     12       0.9912             0.9946          0.9849
# 12     13       0.9913             0.9918          0.9827
# 13     14       0.9922             0.9953          0.9856
# 14     15       0.9936             0.9948          0.9834
# 15     16       0.9938             0.9927          0.9900
# 16     17       0.9928             0.9952          0.9894
# 17     18       0.9951             0.9943          0.9896
# 18     19       0.9934             0.9961          0.9888
# 19     20       0.9933             0.9962          0.9895
# 20     21       0.9955             0.9952          0.9892
# 21     22       0.9947             0.9963          0.9874
# 22     23       0.9956             0.9960          0.9878
# 23     24       0.9957             0.9961          0.9883
# 24     25       0.9956             0.9964          0.9886
# 25     26       0.9958             0.9934          0.9898
# 26     27       0.9950             0.9965          0.9909
# 27     28       0.9951             0.9965          0.9883
# 28     29       0.9956             0.9950          0.9870
# 29     30       0.9954             0.9972          0.9893
#
#     leaky relu (RMSprop)
# 0                 0.9670
# 1                 0.9771
# 2                 0.9827
# 3                 0.9840
# 4                 0.9808
# 5                 0.9845
# 6                 0.9858
# 7                 0.9866
# 8                 0.9852
# 9                 0.9840
# 10                0.9833
# 11                0.9887
# 12                0.9869
# 13                0.9886
# 14                0.9843
# 15                0.9846
# 16                0.9867
# 17                0.9872
# 18                0.9861
# 19                0.9864
# 20                0.9873
# 21                0.9867
# 22                0.9902
# 23                0.9884
# 24                0.9883
# 25                0.9884
# 26                0.9894
# 27                0.9891
# 28                0.9870
# 29                0.9889

# %%
epoch=data['epoch']
relu_adam=100*data['relu (Adam)']
leaky_relu_adam=100*data['leaky relu (Adam)']
relu_RMSprop=100*data['relu (RMSprop)']
leaky_relu_RMSprop=100*data['leaky relu (RMSprop)']
fig=plt.figure()
myaxis=fig.add_axes([0.1,0.1,1.6,1.6])
myaxis.plot(epoch,relu_adam,'r',label='relu (Adam)')
myaxis.plot(epoch,leaky_relu_adam,'b',label='leakyrelu (Adam)')
myaxis.plot(epoch,relu_RMSprop,'m',label='relu (RMSprop)')
myaxis.plot(epoch,leaky_relu_RMSprop,'y',label='leakyrelu (RMSprop)')
myaxis.legend()

# %%
from tensorflow.keras.models import load_model
cnn=load_model(r'C:\Users\sk620\Desktop\Major1\archive\fire_and_smoke')

# %%
cnn.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_25 (Conv2D)          (None, 64, 64, 32)        896
#
#  max_pooling2d_25 (MaxPooli  (None, 32, 32, 32)        0
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, 32, 32, 128)       36992
#
#  max_pooling2d_26 (MaxPooli  (None, 16, 16, 128)       0
#  ng2D)
#
#  conv2d_27 (Conv2D)          (None, 16, 16, 256)       295168
#
#  max_pooling2d_27 (MaxPooli  (None, 8, 8, 256)         0
#  ng2D)
#
#  conv2d_28 (Conv2D)          (None, 8, 8, 256)         590080
#
#  max_pooling2d_28 (MaxPooli  (None, 4, 4, 256)         0
#  ng2D)
#
#  conv2d_29 (Conv2D)          (None, 4, 4, 1024)        2360320
#
#  max_pooling2d_29 (MaxPooli  (None, 2, 2, 1024)        0
#  ng2D)
#
#  flatten_5 (Flatten)         (None, 4096)              0
#
#  dense_15 (Dense)            (None, 256)               1048832
#
#  dense_16 (Dense)            (None, 128)               32896
#
#  dense_17 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 4365313 (16.65 MB)
# Trainable params: 4365313 (16.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import PIL
import numpy as np
from tensorflow.keras.models import load_model

# %%
def predict_image(model, image_path, target_size=(64, 64), threshold=0.5):
    testing = image.load_img(image_path, target_size=target_size)
    testing = image.img_to_array(testing)
    testing = testing / 255
    testing = np.expand_dims(testing, axis=0)
    result = model.predict(testing)

    predicted_class = (result[0][0] > threshold).astype(int)

    return predicted_class

# %%
test_image_1=r'C:\Users\sk620\Desktop\Major1\dataset\training\Smoke\000072.jpg'
predicted_class_1 = predict_image(cnn, test_image_1)
# Out:
# 1/1 [==============================] - 0s 266ms/step

# %%
test_image_2=r'C:\Users\sk620\Desktop\forest-fire-detection\dataset\training\Fire\b.png'
predicted_class_2 = predict_image(cnn, test_image_2)
# Out:
# 1/1 [==============================] - 0s 47ms/step

# %%
Categories = ['Fire', 'Smoke']

# %%
image_show_1 = PIL.Image.open(test_image_1)
plt.imshow(image_show_1)
plt.title(Categories[predicted_class_1])
plt.show()

# %%
image_show_2 = PIL.Image.open(test_image_2)
plt.imshow(image_show_2)
plt.title(Categories[predicted_class_2])
plt.show()
