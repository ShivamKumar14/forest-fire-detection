# %%
import tensorflow as tf
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

# %%
training_data_genetation=ImageDataGenerator(
    rescale=1./255,
    vertical_flip=True,
    horizontal_flip=True,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
)

testing_data_generation=ImageDataGenerator(
    rescale=1./255,
    vertical_flip=True,
)

# %%
training_set=training_data_genetation.flow_from_directory(
    r'C:\Users\sk620\Desktop\dataset\training',
    target_size=(64,64),
    color_mode='rgb',
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 9632 images belonging to 2 classes.

# %%
testing_set=training_data_genetation.flow_from_directory(
    r'C:\Users\sk620\Desktop\dataset\testing',
    target_size=(64,64),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 3706 images belonging to 2 classes.

# %%
cnn=tf.keras.Sequential()

cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,padding='same',activation=tf.keras.layers.LeakyReLU(alpha=0.01),input_shape=[64,64,3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2))

cnn.add(tf.keras.layers.Conv2D(filters=128,kernel_size=3,padding='same',activation=tf.keras.layers.LeakyReLU(alpha=0.01)))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2))

cnn.add(tf.keras.layers.Conv2D(filters=256,kernel_size=3,padding='same',activation=tf.keras.layers.LeakyReLU(alpha=0.01)))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2))

cnn.add(tf.keras.layers.Conv2D(filters=256,kernel_size=3,padding='same',activation=tf.keras.layers.LeakyReLU(alpha=0.01)))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2))

cnn.add(tf.keras.layers.Conv2D(filters=1024,kernel_size=3,padding='same',activation=tf.keras.layers.LeakyReLU(alpha=0.01)))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2))

cnn.add(tf.keras.layers.Flatten())

cnn.add(tf.keras.layers.Dense(units=256,activation=tf.keras.layers.LeakyReLU(alpha=0.01)))

cnn.add(tf.keras.layers.Dense(units=128,activation=tf.keras.layers.LeakyReLU(alpha=0.01)))

cnn.add(tf.keras.layers.Dense(units=1,activation="sigmoid"))

# %%
checkpoint=tf.keras.callbacks.ModelCheckpoint(r'C:\Users\sk620\Desktop\archive\fire_and_smoke.h5',
                                            monitor='val_loss',mode="min",
                                            save_best_only=True)

callbacks=checkpoint

# %%
cnn.compile(
    optimizer='RMSprop',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
cnn.fit(
    x=training_set,
    validation_data=testing_set,
    epochs=20,callbacks=callbacks
)
# Out:
# Epoch 1/20
# 301/301 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9093
# C:\Users\sk620\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 301/301 [==============================] - 1068s 4s/step - loss: 0.2304 - accuracy: 0.9093 - val_loss: 0.0894 - val_accuracy: 0.9641
# Epoch 2/20
# 301/301 [==============================] - 834s 3s/step - loss: 0.1226 - accuracy: 0.9616 - val_loss: 0.1152 - val_accuracy: 0.9647
# Epoch 3/20
# 301/301 [==============================] - 485s 2s/step - loss: 0.1205 - accuracy: 0.9611 - val_loss: 0.0795 - val_accuracy: 0.9749
# Epoch 4/20
# 301/301 [==============================] - 392s 1s/step - loss: 0.1123 - accuracy: 0.9657 - val_loss: 0.1040 - val_accuracy: 0.9692
# Epoch 5/20
# 301/301 [==============================] - 381s 1s/step - loss: 0.1024 - accuracy: 0.9666 - val_loss: 0.1828 - val_accuracy: 0.9633
# Epoch 6/20
# 301/301 [==============================] - 374s 1s/step - loss: 0.1068 - accuracy: 0.9652 - val_loss: 0.0788 - val_accuracy: 0.9684
# Epoch 7/20
# 301/301 [==============================] - 365s 1s/step - loss: 0.1053 - accuracy: 0.9669 - val_loss: 0.0635 - val_accuracy: 0.9771
# Epoch 8/20
# 301/301 [==============================] - 370s 1s/step - loss: 0.0997 - accuracy: 0.9673 - val_loss: 0.0633 - val_accuracy: 0.9784
# Epoch 9/20
# 301/301 [==============================] - 371s 1s/step - loss: 0.0981 - accuracy: 0.9710 - val_loss: 0.0638 - val_accuracy: 0.9730
# Epoch 10/20
# 301/301 [==============================] - 376s 1s/step - loss: 0.0941 - accuracy: 0.9712 - val_loss: 0.0540 - val_accuracy: 0.9798
# Epoch 11/20
# 301/301 [==============================] - 381s 1s/step - loss: 0.0908 - accuracy: 0.9714 - val_loss: 0.0775 - val_accuracy: 0.9787
# Epoch 12/20
# 301/301 [==============================] - 377s 1s/step - loss: 0.0941 - accuracy: 0.9726 - val_loss: 0.0493 - val_accuracy: 0.9835
# Epoch 13/20
# 301/301 [==============================] - 373s 1s/step - loss: 0.0917 - accuracy: 0.9704 - val_loss: 0.0650 - val_accuracy: 0.9744
# Epoch 14/20
# 301/301 [==============================] - 368s 1s/step - loss: 0.0923 - accuracy: 0.9711 - val_loss: 0.0509 - val_accuracy: 0.9854
# Epoch 15/20
# 301/301 [==============================] - 368s 1s/step - loss: 0.0896 - accuracy: 0.9725 - val_loss: 0.0579 - val_accuracy: 0.9814
# Epoch 16/20
# 301/301 [==============================] - 374s 1s/step - loss: 0.0844 - accuracy: 0.9750 - val_loss: 0.0612 - val_accuracy: 0.9784
# Epoch 17/20
# 301/301 [==============================] - 401s 1s/step - loss: 0.0863 - accuracy: 0.9750 - val_loss: 0.0499 - val_accuracy: 0.9838
# Epoch 18/20
# 301/301 [==============================] - 844s 3s/step - loss: 0.0858 - accuracy: 0.9733 - val_loss: 0.0509 - val_accuracy: 0.9811
# Epoch 19/20
# 301/301 [==============================] - 845s 3s/step - loss: 0.0833 - accuracy: 0.9735 - val_loss: 0.0525 - val_accuracy: 0.9857
# Epoch 20/20
# 301/301 [==============================] - 866s 3s/step - loss: 0.0846 - accuracy: 0.9741 - val_loss: 0.0566 - val_accuracy: 0.9852

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data=pd.read_csv(r'C:\Users\sk620\Desktop\Major1\accuracy_value.csv',delimiter=',')
data
# Out:
#     epoch  relu (Adam)  leaky relu (Adam)  relu (RMSprop)  \
# 0       1       0.9671             0.9731          0.9664
# 1       2       0.9841             0.9750          0.9838
# 2       3       0.9873             0.9837          0.9851
# 3       4       0.9808             0.9861          0.9857
# 4       5       0.9878             0.9897          0.9818
# 5       6       0.9919             0.9905          0.9817
# 6       7       0.9910             0.9918          0.9854
# 7       8       0.9924             0.9916          0.9843
# 8       9       0.9937             0.9943          0.9872
# 9      10       0.9916             0.9926          0.9857
# 10     11       0.9931             0.9928          0.9896
# 11     12       0.9912             0.9946          0.9849
# 12     13       0.9913             0.9918          0.9827
# 13     14       0.9922             0.9953          0.9856
# 14     15       0.9936             0.9948          0.9834
# 15     16       0.9938             0.9927          0.9900
# 16     17       0.9928             0.9952          0.9894
# 17     18       0.9951             0.9943          0.9896
# 18     19       0.9934             0.9961          0.9888
# 19     20       0.9933             0.9962          0.9895
# 20     21       0.9955             0.9952          0.9892
# 21     22       0.9947             0.9963          0.9874
# 22     23       0.9956             0.9960          0.9878
# 23     24       0.9957             0.9961          0.9883
# 24     25       0.9956             0.9964          0.9886
# 25     26       0.9958             0.9934          0.9898
# 26     27       0.9950             0.9965          0.9909
# 27     28       0.9951             0.9965          0.9883
# 28     29       0.9956             0.9950          0.9870
# 29     30       0.9954             0.9972          0.9893
#
#     leaky relu (RMSprop)
# 0                 0.9670
# 1                 0.9771
# 2                 0.9827
# 3                 0.9840
# 4                 0.9808
# 5                 0.9845
# 6                 0.9858
# 7                 0.9866
# 8                 0.9852
# 9                 0.9840
# 10                0.9833
# 11                0.9887
# 12                0.9869
# 13                0.9886
# 14                0.9843
# 15                0.9846
# 16                0.9867
# 17                0.9872
# 18                0.9861
# 19                0.9864
# 20                0.9873
# 21                0.9867
# 22                0.9902
# 23                0.9884
# 24                0.9883
# 25                0.9884
# 26                0.9894
# 27                0.9891
# 28                0.9870
# 29                0.9889

# %%
epoch=data['epoch']
relu_adam=100*data['relu (Adam)']
leaky_relu_adam=100*data['leaky relu (Adam)']
relu_RMSprop=100*data['relu (RMSprop)']
leaky_relu_RMSprop=100*data['leaky relu (RMSprop)']
fig=plt.figure()
myaxis=fig.add_axes([0.1,0.1,1.6,1.6])
myaxis.plot(epoch,relu_adam,'r',label='relu (Adam)')
myaxis.plot(epoch,leaky_relu_adam,'b',label='leakyrelu (Adam)')
myaxis.plot(epoch,relu_RMSprop,'m',label='relu (RMSprop)')
myaxis.plot(epoch,leaky_relu_RMSprop,'y',label='leakyrelu (RMSprop)')
myaxis.legend()

# %%
from tensorflow.keras.models import load_model
cnn=load_model(r'C:\Users\sk620\Desktop\archive\fire_and_smoke.h5')

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 32, 32, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       36992
#
#  max_pooling2d_1 (MaxPoolin  (None, 16, 16, 128)       0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)       295168
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 256)         590080
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 1024)        2360320
#
#  max_pooling2d_4 (MaxPoolin  (None, 2, 2, 1024)        0
#  g2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 256)               1048832
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 4365313 (16.65 MB)
# Trainable params: 4365313 (16.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import PIL
import numpy as np
from tensorflow.keras.models import load_model

# %%
test_image=r'C:\Users\sk620\Desktop\dataset\training\smoke\0002.jpg'

# %%
testing=image.load_img(test_image,target_size=(64,64))
testing=image.img_to_array(testing)
testing=testing/255
testing=np.expand_dims(testing,axis=0)
result=cnn.predict(testing)

Categories=['Fire','Smoke']

image_show=PIL.Image.open(test_image)
plt.imshow(image_show)

plt.title(Categories[int(result[0][0])])
plt.show()
# Out:
# 1/1 [==============================] - 1s 754ms/step

# %%
test_image=r'C:\Users\sk620\Desktop\dataset\training\fire\a.png'

# %%
testing=image.load_img(test_image,target_size=(64,64))
testing=image.img_to_array(testing)
testing=testing/255
testing=np.expand_dims(testing,axis=0)
result=cnn.predict(testing)

Categories=['Fire','Smoke']

image_show=PIL.Image.open(test_image)
plt.imshow(image_show)

plt.title(Categories[int(result[0][0])])
plt.show()
# Out:
# 1/1 [==============================] - 0s 103ms/step
